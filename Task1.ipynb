# %%
import pandas as pd
import numpy as np
data=pd.read_excel("sample_dataset.xlsx")
print(data)
# Out:
#     Name   Age Department   Salary        Date
# 0   Amit  22.0        CSE  25000.0  01-01-2025
# 1   Neha   NaN        ECE  30000.0  02/01/2025
# 2  Rahul  21.0       cse       NaN  2025-01-03
# 3  Priya  23.0         ME  40000.0  04-01-2025
# 4  Karan  24.0        CSE  50000.0  05/01/2025
# 5  Sneha  22.0        NaN  35000.0         NaN
# 6   Amit  22.0        CSE  25000.0  01-01-2025
# 7    NaN  25.0        ECE  45000.0  07-01-2025

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#     Name   Age Department   Salary        Date
# 0   Amit  22.0        CSE  25000.0  01-01-2025
# 1   Neha   NaN        ECE  30000.0  02/01/2025
# 2  Rahul  21.0       cse       NaN  2025-01-03
# 3  Priya  23.0         ME  40000.0  04-01-2025
# 4  Karan  24.0        CSE  50000.0  05/01/2025
# 5  Sneha  22.0        NaN  35000.0         NaN
# 6   Amit  22.0        CSE  25000.0  01-01-2025
# 7    NaN  25.0        ECE  45000.0  07-01-2025

# %%
print(df.head())
# Out:
#     Name   Age Department   Salary        Date
# 0   Amit  22.0        CSE  25000.0  01-01-2025
# 1   Neha   NaN        ECE  30000.0  02/01/2025
# 2  Rahul  21.0       cse       NaN  2025-01-03
# 3  Priya  23.0         ME  40000.0  04-01-2025
# 4  Karan  24.0        CSE  50000.0  05/01/2025

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 7 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      str
#  1   Age         7 non-null      int64
#  2   Department  6 non-null      str
#  3   Salary      7 non-null      float64
#  4   Date        3 non-null      str
# dtypes: float64(1), int64(1), str(3)
# memory usage: 336.0 bytes
# None

# %%
print("\nMissing Values:\n")
print(df.isnull().sum())
# Out:
# Missing Values:
#
# Name          1
# Age           1
# Department    1
# Salary        1
# Date          1
# dtype: int64
#
# Duplicate Rows: 1

# %%
print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 1

# %%
import numpy as np
import pandas as pd


num_cols = df.select_dtypes(include='number').columns

for col in num_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')
    df[col] = df[col].fillna(df[col].mean())
print(df[col])
# Out:
# 0    25000.000000
# 1    30000.000000
# 2    35714.285714
# 3    40000.000000
# 4    50000.000000
# 5    35000.000000
# 6    25000.000000
# 7    45000.000000
# Name: Salary, dtype: float64

# %%
duplicates=df.drop_duplicates(inplace=True)
print(duplicates)
# Out:
# None

# %%
if 'Date' in df.columns:
    df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
    print(df['Date'])
# Out:
# 0   2025-01-01
# 1          NaT
# 2          NaT
# 3   2025-04-01
# 4          NaT
# 5          NaT
# 7   2025-07-01
# Name: Date, dtype: datetime64[us]

# %%
if 'Age' in df.columns:
    df['Age'] = df['Age'].astype(int)

print(df['Age'])
# Out:
# 0    22
# 1    22
# 2    21
# 3    23
# 4    24
# 5    22
# 7    25
# Name: Age, dtype: int64

# %%
for col in cat_cols:
    df[col] = df[col].astype(str).str.lower().str.strip()
print(df[col])
# Out:
# 0    2025-01-01
# 1           NaN
# 2           NaN
# 3    2025-04-01
# 4           NaN
# 5           NaN
# 7    2025-07-01
# Name: Date, dtype: str

# %%
for col in num_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower) & (df[col] <= upper)]
print(df)
# Out:
#     Name  Age Department        Salary        Date
# 0   amit   22        cse  25000.000000  2025-01-01
# 1   neha   22        ece  30000.000000         NaN
# 2  rahul   21        cse  35714.285714         NaN
# 3  priya   23         me  40000.000000  2025-04-01
# 4  karan   24        cse  50000.000000         NaN
# 5  sneha   22        NaN  35000.000000         NaN
# 7    NaN   25        ece  45000.000000  2025-07-01

# %%
clean=df.to_csv("cleaned_dataset.csv", index=False)
print(clean)
# Out:
# None

# %%
print("\nCleaned Dataset:\n")
print(df.head())
# Out:
# Cleaned Dataset:
#
#     Name  Age Department        Salary        Date
# 0   amit   22        cse  25000.000000  2025-01-01
# 1   neha   22        ece  30000.000000         NaN
# 2  rahul   21        cse  35714.285714         NaN
# 3  priya   23         me  40000.000000  2025-04-01
# 4  karan   24        cse  50000.000000         NaN

# %%
print("\nFinal Dataset Shape:", df.shape)
# Out:
# Final Dataset Shape: (7, 5)
